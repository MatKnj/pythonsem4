# %% [markdown]
# # Zaawansowane programowanie w Pythonie
#
# # prezentuje:
#
# ### Numba
#
# ---

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

import numba as nb          # <- o tutaj

from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %%
#losowanie tablicy


def tablica(n):

    tablica = np.random.randint(0, 2, (n, n))

    for i in range(n):
        for j in range(n):
            if tablica[i][j] == 0:
                tablica[i][j] = -1


    return tablica

# %%
sym0 = tablica(100)

plt.imshow(sym0)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(99.5), np.float64(-0.5))

# %%
# magnetyzacja = 1/N**2 * suma(s_i)

#energia H = -J*suma_po_sasiadach(s_i*s_j) - B*suma(s_i)

#delta E = 2*s_i * ( J*suma_po_sąsiadach(s_j) + B )

# %%
#delta E

def mikrokrok(state, i, j, J, B, beta):
    height, width = state.shape

    count = 0

    for di in range(-1, 2):
        for dj in range(-1, 2):
            if di != 0 and dj != 0:
                ni = (i + di) % height
                nj = (j + dj) % width

                count += state[ni][nj]


    delta = 2 * state[i][j] * (J * count + B)

    if delta < 0:
        return -1 * state[i][j]

    else:
        if np.random.rand() <= np.exp(-1 * beta * delta):
            return -1 * state[i][j]

        else:
            return state[i][j]

# %%
#magnetyzacja

def magnetyzacja(state):

    height, width = state.shape

    return np.sum(state)/(height*width)

# %%
#energia

def energiaH(state, J, B):
    H = -1 * B * np.sum(state)

    height, width = state.shape

    sumy_sasiadow = 0

    for i in range(height):
        for j in range(width):

            count = -state[i][j]

            for di in range(-1, 2):
                for dj in range(-1, 2):

                    ni = (i + di) % height
                    nj = (j + dj) % width

                    count += state[ni][nj]

            sumy_sasiadow += count


    H += -1 * J * sumy_sasiadow /2

    return H

# %%
#def makrokrok(state, J, B, beta):

    #height, width = state.shape

    #next_state = np.zeros_like(state)

    #for i in range(height):
        #for j in range(width):

            #next_state[i][j] = mikrokrok(state, i, j, J, B, beta)


    #return next_state

# %%
#poprawka


def makrokrok(state, J, B, beta):

    height, width = state.shape

    next_state = state.copy()

    for n in range(height * width):
        
        i = np.random.randint(0, height)
        j = np.random.randint(0, width)

        next_state[i][j] = mikrokrok(state, i, j, J, B, beta)


    return next_state

# %%
def symulacja(M, N, J, B, beta):
    state = tablica(N)

    history = [state]
    E_history = [energiaH(state, J, B)]
    M_history = [magnetyzacja(state)]


    for i in range(M):
        state = makrokrok(state, J, B, beta)
        history.append(state)
        E_history.append(energiaH(state, J, B))
        M_history.append(magnetyzacja(state))


    return history, E_history, M_history

# %%
stany, energie, magnetyzacje = symulacja(100, 100, 1, 0, 0.6)

# %%
def wykres_magn(magn):

    t = []
    for i in range(len(magn)):
        t.append(i)

    plt.plot(t, magn, 'blue')
    plt.xlabel('Numer kroku czasowego')
    plt.ylabel('Magnetyzacja')
    plt.grid(which='both')
    plt.title('Wykres magnetyzacji m(t)')
    plt.show()

# %%
def wykres_energ(energ):

    t = []
    for i in range(len(energ)):
        t.append(i)

    plt.plot(t, energ, 'red')
    plt.xlabel('Numer kroku czasowego')
    plt.ylabel('Energia')
    plt.grid(which='both')
    plt.title('Wykres energii całkowitej w czasie')
    plt.show()

# %%
wykres_magn(magnetyzacje)
wykres_energ(energie)

# %%
fig = plt.figure(figsize=(4, 4))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
plt.axis('off')

img = plt.imshow(stany[0])

def update(i):
    img.set_data(stany[i])
    return img,

ani = FuncAnimation(fig, update, frames= len(stany), interval= 50, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5fda3b3b4b2648a0b61cc58a24ef54e5">
#   <div class="anim-controls">
#     <input id="_anim_slider5fda3b3b4b2648a0b61cc58a24ef54e5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5fda3b3b4b2648a0b61cc58a24ef54e5.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5fda3b3b4b2648a0b61cc58a24ef54e5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5fda3b3b4b2648a0b61cc58a24ef54e5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5fda3b3b4b2648a0b61cc58a24ef54e5"
#              >
#       <label for="_anim_radio1_5fda3b3b4b2648a0b61cc58a24ef54e5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5fda3b3b4b2648a0b61cc58a24ef54e5"
#              checked>
#       <label for="_anim_radio2_5fda3b3b4b2648a0b61cc58a24ef54e5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5fda3b3b4b2648a0b61cc58a24ef54e5"
#              >
#       <label for="_anim_radio3_5fda3b3b4b2648a0b61cc58a24ef54e5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5fda3b3b4b2648a0b61cc58a24ef54e5";
#     var slider_id = "_anim_slider5fda3b3b4b2648a0b61cc58a24ef54e5";
#     var loop_select_id = "_anim_loop_select5fda3b3b4b2648a0b61cc58a24ef54e5";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGA1J

# %% [markdown]
# # symulacja wersja zwykła

# %%
N = 100
beta = 0.6
J = 1
B = 0
M = 100

stany, energie, magnetyzacje = symulacja(M, N, J, B, beta)
    
wykres_magn(magnetyzacje)
wykres_energ(energie)

fig = plt.figure(figsize=(4, 4))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
plt.axis('off')

img = plt.imshow(stany[0])

def update(i):
    img.set_data(stany[i])
    return img,

ani = FuncAnimation(fig, update, frames= len(stany), interval= 50, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcecf977f1af7424b86d2ba7df814b931">
#   <div class="anim-controls">
#     <input id="_anim_slidercecf977f1af7424b86d2ba7df814b931" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcecf977f1af7424b86d2ba7df814b931.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcecf977f1af7424b86d2ba7df814b931.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcecf977f1af7424b86d2ba7df814b931.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcecf977f1af7424b86d2ba7df814b931.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcecf977f1af7424b86d2ba7df814b931.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcecf977f1af7424b86d2ba7df814b931.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcecf977f1af7424b86d2ba7df814b931.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcecf977f1af7424b86d2ba7df814b931.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcecf977f1af7424b86d2ba7df814b931.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcecf977f1af7424b86d2ba7df814b931.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcecf977f1af7424b86d2ba7df814b931"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cecf977f1af7424b86d2ba7df814b931"
#              >
#       <label for="_anim_radio1_cecf977f1af7424b86d2ba7df814b931">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cecf977f1af7424b86d2ba7df814b931"
#              checked>
#       <label for="_anim_radio2_cecf977f1af7424b86d2ba7df814b931">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cecf977f1af7424b86d2ba7df814b931"
#              >
#       <label for="_anim_radio3_cecf977f1af7424b86d2ba7df814b931">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcecf977f1af7424b86d2ba7df814b931";
#     var slider_id = "_anim_slidercecf977f1af7424b86d2ba7df814b931";
#     var loop_select_id = "_anim_loop_selectcecf977f1af7424b86d2ba7df814b931";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGARJ

# %% [markdown]
# ---
# # wersja Numba
# ---

# %%
#losowanie tablicy

@nb.njit
def nb_tablica(n):

    tablica = np.random.randint(0, 2, (n, n))

    for i in range(n):
        for j in range(n):
            if tablica[i][j] == 0:
                tablica[i][j] = -1


    return tablica

# %%
#delta E

@nb.njit
def nb_mikrokrok(state, i, j, J, B, beta):
    height, width = state.shape

    count = 0

    for di in range(-1, 2):
        for dj in range(-1, 2):
            #if di != 0 and dj != 0:
            if not (di == 0 and dj == 0):

                ni = (i + di) % height
                nj = (j + dj) % width

                count += state[ni][nj]


    delta = 2 * state[i][j] * (J * count + B)

    if delta < 0:
        return -1 * state[i][j]

    else:
        if np.random.rand() <= np.exp(-1 * beta * delta):
            return -1 * state[i][j]

        else:
            return state[i][j]

# %%
#magnetyzacja

@nb.njit
def nb_magnetyzacja(state): 
    
    height, width = state.shape 

    return np.sum(state)/(height*width)

# %%
#energia

@nb.njit
def nb_energiaH(state, J, B):
    H = -1 * B * np.sum(state)

    height, width = state.shape

    sumy_sasiadow = 0

    for i in range(height):
        for j in range(width):

            #count = -state[i][j]

            #for di in range(-1, 2):
                #for dj in range(-1, 2):

                    #ni = (i + di) % height
                    #nj = (j + dj) % width

                    #count += state[ni][nj]

            count = 0

            for di in range(-1, 2):
                for dj in range(-1, 2):
                    if not (di == 0 and dj == 0):

                        ni = (i + di) % height
                        nj = (j + dj) % width

                        count += state[ni][nj]

            sumy_sasiadow += count * state[i][j]


    H += -1 * J * sumy_sasiadow / 2

    return H

# %%
#@nb.njit
#def nb_makrokrok(state, J, B, beta):

    #height, width = state.shape

    #next_state = np.zeros_like(state)

    #for i in range(height):
        #for j in range(width):

            #next_state[i][j] = nb_mikrokrok(state, i, j, J, B, beta)

####################
    #return next_state

# %%
#poprawiony makrokrok

@nb.njit
def nb_makrokrok(state, J, B, beta):

    height, width = state.shape

    next_state = state.copy()

    for n in range(height * width):
        
        i = np.random.randint(0, height)
        j = np.random.randint(0, width)

        #next_state[i][j] = nb_mikrokrok(state, i, j, J, B, beta)
        next_state[i][j] = nb_mikrokrok(next_state, i, j, J, B, beta)


    return next_state

# %%
@nb.njit
def nb_symulacja(M, N, J, B, beta):
    state = nb_tablica(N)

    history = [state]
    E_history = [nb_energiaH(state, J, B)]
    M_history = [nb_magnetyzacja(state)]


    for i in range(M):
        state = nb_makrokrok(state, J, B, beta)
        history.append(state)
        E_history.append(nb_energiaH(state, J, B))
        M_history.append(nb_magnetyzacja(state))


    return history, E_history, M_history

# %% [markdown]
# # symulacja wersja numba

# %%
N = 400
beta = 0.6
J = 1
B = 0
M = 100

stany, energie, magnetyzacje = nb_symulacja(M, N, J, B, beta)
    
wykres_magn(magnetyzacje)
wykres_energ(energie)

#plt.plot(np.array(magnetyzacje)/np.array(energie), 'red')
#plt.show()

fig = plt.figure(figsize=(4, 4))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
plt.axis('off')

img = plt.imshow(stany[0])

def update(i):
    img.set_data(stany[i])
    return img,

ani = FuncAnimation(fig, update, frames= len(stany), interval= 50, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img96d1027af8874819a403e5dc40bbb7ee">
#   <div class="anim-controls">
#     <input id="_anim_slider96d1027af8874819a403e5dc40bbb7ee" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim96d1027af8874819a403e5dc40bbb7ee.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim96d1027af8874819a403e5dc40bbb7ee.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim96d1027af8874819a403e5dc40bbb7ee.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim96d1027af8874819a403e5dc40bbb7ee.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim96d1027af8874819a403e5dc40bbb7ee.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim96d1027af8874819a403e5dc40bbb7ee.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim96d1027af8874819a403e5dc40bbb7ee.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim96d1027af8874819a403e5dc40bbb7ee.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim96d1027af8874819a403e5dc40bbb7ee.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim96d1027af8874819a403e5dc40bbb7ee.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select96d1027af8874819a403e5dc40bbb7ee"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_96d1027af8874819a403e5dc40bbb7ee"
#              >
#       <label for="_anim_radio1_96d1027af8874819a403e5dc40bbb7ee">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_96d1027af8874819a403e5dc40bbb7ee"
#              checked>
#       <label for="_anim_radio2_96d1027af8874819a403e5dc40bbb7ee">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_96d1027af8874819a403e5dc40bbb7ee"
#              >
#       <label for="_anim_radio3_96d1027af8874819a403e5dc40bbb7ee">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img96d1027af8874819a403e5dc40bbb7ee";
#     var slider_id = "_anim_slider96d1027af8874819a403e5dc40bbb7ee";
#     var loop_select_id = "_anim_loop_select96d1027af8874819a403e5dc40bbb7ee";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAztZJ
